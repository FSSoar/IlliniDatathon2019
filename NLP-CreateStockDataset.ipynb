# %%
import pandas as pd
import numpy as np
from newsapi import NewsApiClient
from datetime import datetime, timedelta

# %%
key = '8b8428b3603940ef8485d39a6eb526f2'
news = NewsApiClient(api_key=key)

companiesTotal = {'Synchrony Financial': [],
            '3M': [],
            'Bayer': [],
            'Honeywell': []}

ARTICLE_COUNT = 5
# finds the relevant news articles for a company on a day
# current_date should be in form "YYYY-MM-DAY"
def parse_articles_on_date(company_name, current_date):
    # this calculates the day one week ago
    DAYS_BACK = 7
    year, month, day = tuple(current_date.split('-'))
    new_date = datetime(int(year), int(month), int(day)) - timedelta(DAYS_BACK)
    start_day = str(new_date)[:10]
    
    company_data = []
    query = company_name + " Company News"
    all_articles = news.get_everything(q=query, from_param=start_day,to=current_date, language='en', sort_by='relevancy')
    article_data = all_articles['articles']
    for i in range(ARTICLE_COUNT):
        try:
            titlePlusSummary = article_data[i]['title'] + '. ' + article_data[i]['description']
            company_data.append(titlePlusSummary)
        except:
            break
    return company_data

# takes data found from parse_articles_on_date and determines the score using the classifier
def calculate_score(classifer, company_data):
    count = 0
    output = 0
    for summary in company_data:
        try:
            output += classifier.prob_classify(summary).prob(1)
            count += 1
        except:
            continue
    if count > 0:
        return output / count
    else:
        return 0

# a wrapper on the previous two functions
def article_scorer_wrapper(classifier, company_name, current_date):
    company_data = parse_articles_on_date(company_name, current_date)
    return calculate_score(classifier, company_data)

# %%
def create_close_open_ratio(df):
    df["Close-Open Ratio"] = (df['close'].values-df['open'].values)/df['open'].values
    ratios = df["Close-Open Ratio"].values
    ratios += np.abs(np.min(ratios))
    ratios /= np.max(ratios, axis=0)
    df["Close-Open Ratio"] = ratios
    return df

# %%
PATH = 'data/MMM-TIME_SERIES_DAILY.csv'
dateColumn = "timestamp"

df_MMM = pd.read_csv(PATH, low_memory=False, parse_dates=[dateColumn])
df_MMM = create_close_open_ratio(df_MMM)

# %%
df_MMM.head()
# Out:
#    timestamp    open    high     low   close   volume  Close-Open Ratio
# 0 2019-02-15  206.46  208.97  206.00  208.86  2000378          0.515954
# 1 2019-02-14  206.59  207.12  204.05  204.93  2229753          0.391018
# 2 2019-02-13  207.09  210.40  206.59  209.72  2967332          0.522787
# 3 2019-02-12  202.87  206.79  202.19  206.57  2622973          0.557984
# 4 2019-02-11  200.93  201.20  199.64  200.91  1513457          0.441448

# %%
def create_sentiment_dataset(df, company_name):
    for i in range(len(df)):
        date = str(df['timestamp'][i])[:10]
        # the API won't let me pull more than a month back, so this is an ad-hoc fix
        if date == '2019-01-23':
            break
        articles = parse_articles_on_date(company_name=company_name, current_date=date)
        toAdd = pd.DataFrame({'statement': articles,
                              'close-open ratio': df['Close-Open Ratio'][i]})
        if (i == 0):
            df_NLP = toAdd
        else:
            df_NLP = df_NLP.append(toAdd, ignore_index=True)
            
    return df_NLP

# %%
df_NLP = create_sentiment_dataset(df_MMM, "3M")
# Out:
# 2019-02-15
# 2019-02-14
# 2019-02-13
# 2019-02-12
# 2019-02-11
# 2019-02-08
# 2019-02-07
# 2019-02-06
# 2019-02-05
# 2019-02-04
# 2019-02-01
# 2019-01-31
# 2019-01-30
# 2019-01-29
# 2019-01-28
# 2019-01-25
# 2019-01-24
# 2019-01-23
#                                            statement  close-open ratio
# 0  EPA Announced A Plan For Toxic Chemicals In Dr...          0.515954
# 1  Deep Dive: These stocks rose the most as Washi...          0.515954
# 2  Maria Ressa arrest: everything you need to kno...          0.515954
# 3  Wall Street rises on trade hopes, deal to avoi...          0.515954
# 4  Stocks in the news: Hindalco, Axis Bank, Max I...          0.515954

# %%
df_NLP
# Out:
#                                             statement  close-open ratio
# 0   EPA Announced A Plan For Toxic Chemicals In Dr...          0.515954
# 1   Deep Dive: These stocks rose the most as Washi...          0.515954
# 2   Maria Ressa arrest: everything you need to kno...          0.515954
# 3   Wall Street rises on trade hopes, deal to avoi...          0.515954
# 4   Stocks in the news: Hindalco, Axis Bank, Max I...          0.515954
# 5   EPA Announced A Plan For Toxic Chemicals In Dr...          0.391018
# 6   Deaths put e-scooters in spotlight. A watchdog...          0.391018
# 7   Deep Dive: These stocks rose the most as Washi...          0.391018
# 8   Morning Brew claims 1 million subscribers, $3m...          0.391018
# 9   Maria Ressa arrest: everything you need to kno...          0.391018
# 10  Deaths put e-scooters in spotlight. A watchdog...          0.522787
# 11  Deep Dive: These stocks rose the most as Washi...          0.522787
# 12  Morning Brew claims 1 million subscribers, $3m...          0.522787
# 13  Wall Street rises on trade hopes, deal to avoi...          0.522787
# 14  Stocks in the news: Hindalco, Axis Bank, Max I...          0.522787
# 15  Deaths put e-scooters in spotlight. A watchdog...          0.557984
# 16  Deep Dive: These stocks rose the most as Washi...          0.557984
# 17  Chinese investors buy West Carrollton warehous...          0.557984
# 18  Morning Brew claims 1 million subscribers, $3m...          0.557984
# 19  Wall Street rises on trade hopes, deal to avoi...          0.557984
# 20  Deaths put e-scooters in spotlight. A watchdog...          0.441448
# 21  Capital Confidential: Brexit gets personal for...          0.441448
# 22  Chinese investors buy West Carrollton warehous...          0.441448
# 23  Morning Brew claims 1 million subscribers, $3m...          0.441448
# 24  China Hospital Supplies Market Outlook to 2025...          0.441448
# 25  3M Opens 2019 on an Unimpressive Note. There w...          0.461220
# 26  Deaths put e-scooters in spotlight. A watchdog...          0.461220
# 27  Capital Confidential: Brexit gets personal for...          0.461220
# 28  Chinese investors buy West Carrollton warehous...          0.461220
# 29  Morning Brew claims 1 million subscribers, $3m...          0.461220
# ..                                                ...               ...
# 55  Stocks Open Slightly Higher on Upbeat Earnings...          0.490030
# 56  Need to Know: The global dominators you invest...          0.490030
# 57  3M (MMM) Q4 2018 Earnings Conference Call Tran...          0.490030
# 58  China's factory activity shrinks as slowdown w...          0.490030
# 59  World's top creators headline Design Indaba 20...          0.490030
# 60  Stocks Open Slightly Higher on Upbeat Earnings...          0.475744
# 61  Need to Know: The global dominators you invest...          0.475744
# 62  3M (MMM) Q4 2018 Earnings Conference Call Tran...          0.475744
# 63  World's top creators headline Design Indaba 20...          0.475744
# 64  3M's Results Aren't All That Comforting. 3M no...          0.475744
# 65  Stocks Open Slightly Higher on Upbeat Earnings...          0.505301
# 66  Need to Know: The global dominators you invest...          0.505301
# 67  World's top creators headline Design Indaba 20...          0.505301
# 68  3M's Results Aren't All That Comforting. 3M no...          0.505301
# 69  Wall Street set to open higher on strong earni...          0.505301
# 70  World's top creators headline Design Indaba 20...          0.444055
# 71  Wall Street set to open higher on strong earni...          0.444055
# 72  Geopolitics Aside, How About Those Earnings? I...          0.444055
# 73  Vanadium Miners News For The Month Of January ...          0.444055
# 74  Consumer finance journalist Martin Lewis drops...          0.444055
# 75  3M Company: 2019 To Be A Likely Dissappointmen...          0.480592
# 76  World's top creators headline Design Indaba 20...          0.480592
# 77  Wall Street set to open higher on strong earni...          0.480592
# 78  Geopolitics Aside, How About Those Earnings? I...          0.480592
# 79  Consumer finance journalist Martin Lewis drops...          0.480592
# 80  3M Company: 2019 To Be A Likely Dissappointmen...          0.450675
# 81  World's top creators headline Design Indaba 20...          0.450675
# 82  Wall Street set to open higher on strong earni...          0.450675
# 83  Geopolitics Aside, How About Those Earnings? I...          0.450675
# 84  Consumer finance journalist Martin Lewis drops...          0.450675
#
# [85 rows x 2 columns]
